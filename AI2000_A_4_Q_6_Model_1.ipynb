# %% [markdown]
# # **Author: Vijay Varma - AI20BTECH11012**
#
# # **Kaggle Display Name : AI20BTECH11012**

# %% [markdown]
# # **Model 1 using LGBM**

# %% [markdown]
# # **Downloading Data from Kaggle**

# %%
! pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle competitions download -c new-york-city-taxi-fare-prediction
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# Downloading train.csv.zip to /content
# 100% 1.56G/1.56G [00:40<00:00, 32.6MB/s]
# 100% 1.56G/1.56G [00:40<00:00, 41.6MB/s]
# Downloading GCP-Coupons-Instructions.rtf to /content
#   0% 0.00/486 [00:00<?, ?B/s]
# 100% 486/486 [00:00<00:00, 443kB/s]
# Downloading sample_submission.csv to /content
#   0% 0.00/335k [00:00<?, ?B/s]
# 100% 335k/335k [00:00<00:00, 101MB/s]
# Downloading test.csv to /content
#   0% 0.00/960k [00:00<?, ?B/s]
# 100% 960k/960k [00:00<00:00, 121MB/s]

# %%
! unzip train.csv.zip
# Out:
# Archive:  train.csv.zip
#   inflating: train.csv

# %%
#### 
# Importing Required Packages
import pandas as pd
import numpy as np
import datetime as dt

# %%
####
# Loading 10000000 rows of tran.csv into df_train

df_train = pd.read_csv("train.csv",nrows=5000000)

# %%
####
# Printing df_train

df_train
# Out:
#                                    key  ...  passenger_count
# 0          2009-06-15 17:26:21.0000001  ...                1
# 1          2010-01-05 16:52:16.0000002  ...                1
# 2         2011-08-18 00:35:00.00000049  ...                2
# 3          2012-04-21 04:30:42.0000001  ...                1
# 4        2010-03-09 07:51:00.000000135  ...                1
# ...                                ...  ...              ...
# 4999995    2011-01-24 21:33:44.0000003  ...                1
# 4999996  2013-10-11 12:12:00.000000118  ...                2
# 4999997    2014-12-06 23:04:28.0000002  ...                2
# 4999998    2015-05-30 19:01:24.0000004  ...                1
# 4999999  2012-07-11 08:12:00.000000102  ...                6
#
# [5000000 rows x 8 columns]

# %%
####
# Loading test.csv into df_test

df_test = pd.read_csv("test.csv")

# %%
####
# Printing df_test

df_test
# Out:
#                               key  ... passenger_count
# 0     2015-01-27 13:08:24.0000002  ...               1
# 1     2015-01-27 13:08:24.0000003  ...               1
# 2     2011-10-08 11:53:44.0000002  ...               1
# 3     2012-12-01 21:12:12.0000002  ...               1
# 4     2012-12-01 21:12:12.0000003  ...               1
# ...                           ...  ...             ...
# 9909  2015-05-10 12:37:51.0000002  ...               6
# 9910  2015-01-12 17:05:51.0000001  ...               6
# 9911  2015-04-19 20:44:15.0000001  ...               6
# 9912  2015-01-31 01:05:19.0000005  ...               6
# 9913  2015-01-18 14:06:23.0000006  ...               6
#
# [9914 rows x 7 columns]

# %%
#### 
# Copying train_df, test_df into another dataframes

train_df = df_train.copy()
test_df = df_test.copy()

# %%
####
# Let's get an understanding of our data
# Let's print a snapshot of our train data frame 
# train data frame

train_df
# Out:
#                                    key  ...  passenger_count
# 0          2009-06-15 17:26:21.0000001  ...                1
# 1          2010-01-05 16:52:16.0000002  ...                1
# 2         2011-08-18 00:35:00.00000049  ...                2
# 3          2012-04-21 04:30:42.0000001  ...                1
# 4        2010-03-09 07:51:00.000000135  ...                1
# ...                                ...  ...              ...
# 4999995    2011-01-24 21:33:44.0000003  ...                1
# 4999996  2013-10-11 12:12:00.000000118  ...                2
# 4999997    2014-12-06 23:04:28.0000002  ...                2
# 4999998    2015-05-30 19:01:24.0000004  ...                1
# 4999999  2012-07-11 08:12:00.000000102  ...                6
#
# [5000000 rows x 8 columns]

# %%
####
# Printing types of columns in train data frame

print(train_df.dtypes)
# Out:
# key                   object
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %% [markdown]
# # **We have to add 'year', 'month', 'day', 'hour' as features from 'pickup_datetime' column into our train and test data frame.**

# %%
####
# This function adds 'year', 'month', 'day', 'hour' as features from 'pickup_datetime' column into the data frame

def add_date_time(df):
    # splits 'pickup_datetime' into 'year', 'month', 'day'
    df[['year', 'month', 'day']] = df.pickup_datetime.str.split(' ', expand=True).iloc[:,0].str.split('-', expand=True).astype('int64')
    # adds hour into the data frame
    df['hour'] = df.pickup_datetime.str.split(' ', expand=True).iloc[:,1].str.split(':', expand=True).iloc[:,0].astype('int64')

    return df

# %%
####
# Adds 'year', 'month', 'day', 'hour' as features from 'pickup_datetime' column into the train_df

train_df = add_date_time(train_df)

# %%
####
# Printing modified train_df

train_df
# Out:
#                                    key  fare_amount  ... day  hour
# 0          2009-06-15 17:26:21.0000001          4.5  ...  15    17
# 1          2010-01-05 16:52:16.0000002         16.9  ...   5    16
# 2         2011-08-18 00:35:00.00000049          5.7  ...  18     0
# 3          2012-04-21 04:30:42.0000001          7.7  ...  21     4
# 4        2010-03-09 07:51:00.000000135          5.3  ...   9     7
# ...                                ...          ...  ...  ..   ...
# 4999995    2011-01-24 21:33:44.0000003         16.5  ...  24    21
# 4999996  2013-10-11 12:12:00.000000118          9.0  ...  11    12
# 4999997    2014-12-06 23:04:28.0000002         10.5  ...   6    23
# 4999998    2015-05-30 19:01:24.0000004         10.0  ...  30    19
# 4999999  2012-07-11 08:12:00.000000102          4.9  ...  11     8
#
# [5000000 rows x 12 columns]

# %%
####
# Let's get an understanding of our data
# Let's print a snapshot of our test data frame 
# test data frame

test_df
# Out:
#                               key  ... passenger_count
# 0     2015-01-27 13:08:24.0000002  ...               1
# 1     2015-01-27 13:08:24.0000003  ...               1
# 2     2011-10-08 11:53:44.0000002  ...               1
# 3     2012-12-01 21:12:12.0000002  ...               1
# 4     2012-12-01 21:12:12.0000003  ...               1
# ...                           ...  ...             ...
# 9909  2015-05-10 12:37:51.0000002  ...               6
# 9910  2015-01-12 17:05:51.0000001  ...               6
# 9911  2015-04-19 20:44:15.0000001  ...               6
# 9912  2015-01-31 01:05:19.0000005  ...               6
# 9913  2015-01-18 14:06:23.0000006  ...               6
#
# [9914 rows x 7 columns]

# %%
####
# Printing types of columns in test data frame

print(test_df.dtypes)
# Out:
# key                   object
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
####
# Adds 'year', 'month', 'day', 'hour' as features from 'pickup_datetime' column into the train_df

test_df = add_date_time(test_df)

# %%
####
# Printing modified test_df

test_df
# Out:
#                               key          pickup_datetime  ...  day  hour
# 0     2015-01-27 13:08:24.0000002  2015-01-27 13:08:24 UTC  ...   27    13
# 1     2015-01-27 13:08:24.0000003  2015-01-27 13:08:24 UTC  ...   27    13
# 2     2011-10-08 11:53:44.0000002  2011-10-08 11:53:44 UTC  ...    8    11
# 3     2012-12-01 21:12:12.0000002  2012-12-01 21:12:12 UTC  ...    1    21
# 4     2012-12-01 21:12:12.0000003  2012-12-01 21:12:12 UTC  ...    1    21
# ...                           ...                      ...  ...  ...   ...
# 9909  2015-05-10 12:37:51.0000002  2015-05-10 12:37:51 UTC  ...   10    12
# 9910  2015-01-12 17:05:51.0000001  2015-01-12 17:05:51 UTC  ...   12    17
# 9911  2015-04-19 20:44:15.0000001  2015-04-19 20:44:15 UTC  ...   19    20
# 9912  2015-01-31 01:05:19.0000005  2015-01-31 01:05:19 UTC  ...   31     1
# 9913  2015-01-18 14:06:23.0000006  2015-01-18 14:06:23 UTC  ...   18    14
#
# [9914 rows x 11 columns]

# %%
####
# Dropping Columns "pickup_datetime","key" from train_df as they are not used as features in our model

train_df.drop(columns=["pickup_datetime","key"], axis=1, inplace=True)

# %%
####
# Dropping Column "pickup_datetime" from test_df as it is not used as feature in our model

test_df.drop(columns=["pickup_datetime"], axis=1, inplace=True)

# %%
####
# Printing modified train_df

train_df
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  ...  month  day  hour
# 0                4.5        -73.844311        40.721319  ...      6   15    17
# 1               16.9        -74.016048        40.711303  ...      1    5    16
# 2                5.7        -73.982738        40.761270  ...      8   18     0
# 3                7.7        -73.987130        40.733143  ...      4   21     4
# 4                5.3        -73.968095        40.768008  ...      3    9     7
# ...              ...               ...              ...  ...    ...  ...   ...
# 4999995         16.5        -74.003883        40.725772  ...      1   24    21
# 4999996          9.0        -73.995105        40.739897  ...     10   11    12
# 4999997         10.5        -73.981063        40.764125  ...     12    6    23
# 4999998         10.0        -73.965401        40.759140  ...      5   30    19
# 4999999          4.9        -73.972595        40.743177  ...      7   11     8
#
# [5000000 rows x 10 columns]

# %%
####
# Printing modified test_df

test_df
# Out:
#                               key  pickup_longitude  ...  day  hour
# 0     2015-01-27 13:08:24.0000002        -73.973320  ...   27    13
# 1     2015-01-27 13:08:24.0000003        -73.986862  ...   27    13
# 2     2011-10-08 11:53:44.0000002        -73.982524  ...    8    11
# 3     2012-12-01 21:12:12.0000002        -73.981160  ...    1    21
# 4     2012-12-01 21:12:12.0000003        -73.966046  ...    1    21
# ...                           ...               ...  ...  ...   ...
# 9909  2015-05-10 12:37:51.0000002        -73.968124  ...   10    12
# 9910  2015-01-12 17:05:51.0000001        -73.945511  ...   12    17
# 9911  2015-04-19 20:44:15.0000001        -73.991600  ...   19    20
# 9912  2015-01-31 01:05:19.0000005        -73.985573  ...   31     1
# 9913  2015-01-18 14:06:23.0000006        -73.988022  ...   18    14
#
# [9914 rows x 10 columns]

# %% [markdown]
# # **Check if there are any Null Values in any column of our data**

# %%
####
# Checking if there are any Null Values in any column of our train_df

train_df.isnull().sum()
# Out:
# fare_amount           0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude    36
# dropoff_latitude     36
# passenger_count       0
# year                  0
# month                 0
# day                   0
# hour                  0
# dtype: int64

# %%
####
# Checking if there are any Null Values in any column of our test_df

test_df.isnull().sum()
# Out:
# key                  0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# year                 0
# month                0
# day                  0
# hour                 0
# dtype: int64

# %%
####
# Dropping Null Values in the train data

train_df.dropna(inplace=True)

# %%
####
# Printing modified train_df

train_df
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  ...  month  day  hour
# 0                4.5        -73.844311        40.721319  ...      6   15    17
# 1               16.9        -74.016048        40.711303  ...      1    5    16
# 2                5.7        -73.982738        40.761270  ...      8   18     0
# 3                7.7        -73.987130        40.733143  ...      4   21     4
# 4                5.3        -73.968095        40.768008  ...      3    9     7
# ...              ...               ...              ...  ...    ...  ...   ...
# 4999995         16.5        -74.003883        40.725772  ...      1   24    21
# 4999996          9.0        -73.995105        40.739897  ...     10   11    12
# 4999997         10.5        -73.981063        40.764125  ...     12    6    23
# 4999998         10.0        -73.965401        40.759140  ...      5   30    19
# 4999999          4.9        -73.972595        40.743177  ...      7   11     8
#
# [4999964 rows x 10 columns]

# %%
####
# Lets look at the statistics of our train data

train_df.describe()
# Out:
#         fare_amount  pickup_longitude  ...           day          hour
# count  4.999964e+06      4.999964e+06  ...  4.999964e+06  4.999964e+06
# mean   1.134074e+01     -7.250681e+01  ...  1.572073e+01  1.351062e+01
# std    9.820066e+00      1.280962e+01  ...  8.684429e+00  6.516342e+00
# min   -1.000000e+02     -3.426609e+03  ...  1.000000e+00  0.000000e+00
# 25%    6.000000e+00     -7.399206e+01  ...  8.000000e+00  9.000000e+00
# 50%    8.500000e+00     -7.398181e+01  ...  1.600000e+01  1.400000e+01
# 75%    1.250000e+01     -7.396711e+01  ...  2.300000e+01  1.900000e+01
# max    1.273310e+03      3.439426e+03  ...  3.100000e+01  2.300000e+01
#
# [8 rows x 10 columns]

# %%
####
# Printing test_df

test_df
# Out:
#                               key  pickup_longitude  ...  day  hour
# 0     2015-01-27 13:08:24.0000002        -73.973320  ...   27    13
# 1     2015-01-27 13:08:24.0000003        -73.986862  ...   27    13
# 2     2011-10-08 11:53:44.0000002        -73.982524  ...    8    11
# 3     2012-12-01 21:12:12.0000002        -73.981160  ...    1    21
# 4     2012-12-01 21:12:12.0000003        -73.966046  ...    1    21
# ...                           ...               ...  ...  ...   ...
# 9909  2015-05-10 12:37:51.0000002        -73.968124  ...   10    12
# 9910  2015-01-12 17:05:51.0000001        -73.945511  ...   12    17
# 9911  2015-04-19 20:44:15.0000001        -73.991600  ...   19    20
# 9912  2015-01-31 01:05:19.0000005        -73.985573  ...   31     1
# 9913  2015-01-18 14:06:23.0000006        -73.988022  ...   18    14
#
# [9914 rows x 10 columns]

# %%
####
# Lets look at the statistics of our test data

test_df.describe()
# Out:
#        pickup_longitude  pickup_latitude  ...          day         hour
# count       9914.000000      9914.000000  ...  9914.000000  9914.000000
# mean         -73.974722        40.751041  ...    16.194170    13.467420
# std            0.042774         0.033541  ...     8.838482     6.868584
# min          -74.252193        40.573143  ...     1.000000     0.000000
# 25%          -73.992501        40.736125  ...     9.000000     8.000000
# 50%          -73.982326        40.753051  ...    16.000000    15.000000
# 75%          -73.968013        40.767113  ...    25.000000    19.000000
# max          -72.986532        41.709555  ...    31.000000    23.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# # **There are many Outliers in our train data.**
#
# # **We have to remove them so that our model performs better.**
#
# # **We will remove the Outliers Column by Column.**

# %% [markdown]
# # **1. Passenger Count**

# %% [markdown]
# # **We drop the rows in train data where passenger_count is more than 6 (practically not possible).**

# %%
####
# Dropping the Rows where passenger_count > 6 in train_df

train_df = train_df.drop(train_df[train_df['passenger_count']>6].index, axis=0)

# %%
####
# Printing modified train_df

train_df
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  ...  month  day  hour
# 0                4.5        -73.844311        40.721319  ...      6   15    17
# 1               16.9        -74.016048        40.711303  ...      1    5    16
# 2                5.7        -73.982738        40.761270  ...      8   18     0
# 3                7.7        -73.987130        40.733143  ...      4   21     4
# 4                5.3        -73.968095        40.768008  ...      3    9     7
# ...              ...               ...              ...  ...    ...  ...   ...
# 4999995         16.5        -74.003883        40.725772  ...      1   24    21
# 4999996          9.0        -73.995105        40.739897  ...     10   11    12
# 4999997         10.5        -73.981063        40.764125  ...     12    6    23
# 4999998         10.0        -73.965401        40.759140  ...      5   30    19
# 4999999          4.9        -73.972595        40.743177  ...      7   11     8
#
# [4999952 rows x 10 columns]

# %% [markdown]
# # **As the data is about taxi in New York City, we consider only the longitude and latitude in the range of New York City.**

# %% [markdown]
# # **The Latitude and Longitude of New York City is approximately taken from**
#
# # **Latitude : (40.4,41.0)**
#
# # **Longitude : (-74.2,-73.7)**

# %% [markdown]
# # **2. Pickup Longitude**

# %%
####
# Dropping 'pickup_longitude' other than in New York City

train_df = train_df.drop(train_df[train_df['pickup_longitude']<-74.2].index, axis=0)
train_df = train_df.drop(train_df[train_df['pickup_longitude']>-73.7].index, axis=0)

# %%
####
# Dropping 'dropoff_longitude' other than in New York City

train_df = train_df.drop(train_df[train_df['dropoff_longitude']<-74.2].index, axis=0)
train_df = train_df.drop(train_df[train_df['dropoff_longitude']>-73.7].index, axis=0)

# %%
####
# Dropping 'pickup_latitude' other than in New York City

train_df = train_df.drop(train_df[train_df['pickup_latitude']<40.4].index, axis=0)
train_df = train_df.drop(train_df[train_df['pickup_latitude']>41.0].index, axis=0)

# %%
####
# Dropping 'dropoff_latitude' other than in New York City

train_df = train_df.drop(train_df[train_df['dropoff_latitude']<40.4].index, axis=0)
train_df = train_df.drop(train_df[train_df['dropoff_latitude']>41.0].index, axis=0)

# %%
####
# Printing Modified train_df

train_df
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  ...  month  day  hour
# 0                4.5        -73.844311        40.721319  ...      6   15    17
# 1               16.9        -74.016048        40.711303  ...      1    5    16
# 2                5.7        -73.982738        40.761270  ...      8   18     0
# 3                7.7        -73.987130        40.733143  ...      4   21     4
# 4                5.3        -73.968095        40.768008  ...      3    9     7
# ...              ...               ...              ...  ...    ...  ...   ...
# 4999995         16.5        -74.003883        40.725772  ...      1   24    21
# 4999996          9.0        -73.995105        40.739897  ...     10   11    12
# 4999997         10.5        -73.981063        40.764125  ...     12    6    23
# 4999998         10.0        -73.965401        40.759140  ...      5   30    19
# 4999999          4.9        -73.972595        40.743177  ...      7   11     8
#
# [4888546 rows x 10 columns]

# %% [markdown]
# # **3. Fare Amount**

# %% [markdown]
# # **Generally Fare Amount lies in between 2 to 100.**

# %%
####
# Dropping 'fare_amount' other than 2 to 100

train_df = train_df.drop(train_df[train_df['fare_amount']<=2].index, axis=0)
train_df = train_df.drop(train_df[train_df['fare_amount']>100].index, axis=0)

# %%
####
# Printing Modified train_df

train_df
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  ...  month  day  hour
# 0                4.5        -73.844311        40.721319  ...      6   15    17
# 1               16.9        -74.016048        40.711303  ...      1    5    16
# 2                5.7        -73.982738        40.761270  ...      8   18     0
# 3                7.7        -73.987130        40.733143  ...      4   21     4
# 4                5.3        -73.968095        40.768008  ...      3    9     7
# ...              ...               ...              ...  ...    ...  ...   ...
# 4999995         16.5        -74.003883        40.725772  ...      1   24    21
# 4999996          9.0        -73.995105        40.739897  ...     10   11    12
# 4999997         10.5        -73.981063        40.764125  ...     12    6    23
# 4999998         10.0        -73.965401        40.759140  ...      5   30    19
# 4999999          4.9        -73.972595        40.743177  ...      7   11     8
#
# [4887307 rows x 10 columns]

# %% [markdown]
# # **Now, we have to split train_df into train_x (contains only features) and train_y (contains only labels).**

# %%
####
# Copying train_df into a new Data Frame

train_x = train_df.copy()

# %%
####
# Extracting 'fare_amount' Column into train_y list

train_y = train_df['fare_amount'].to_list()

# Dropping 'fare_amount' Column from train_x Data Frame

train_x.drop(columns=['fare_amount'],axis=1,inplace = True)

# %%
####
# Copying test_df into a new Data Frame

test_x = test_df.copy()

# %%
####
# Extracting 'key' Column into test_id list

test_key = test_df["key"].to_list()

# Dropping 'key' Column from test_x Data Frame

test_x.drop(columns=["key"],axis=1,inplace = True)

# %%
####
# Printing test_key

test_key
# Out:
# ['2015-01-27 13:08:24.0000002',
#  '2015-01-27 13:08:24.0000003',
#  '2011-10-08 11:53:44.0000002',
#  '2012-12-01 21:12:12.0000002',
#  '2012-12-01 21:12:12.0000003',
#  '2012-12-01 21:12:12.0000005',
#  '2011-10-06 12:10:20.0000001',
#  '2011-10-06 12:10:20.0000003',
#  '2011-10-06 12:10:20.0000002',
#  '2014-02-18 15:22:20.0000002',
#  '2010-08-14 02:13:00.000000149',
#  '2010-08-14 02:13:00.00000054',
#  '2010-08-14 02:13:00.000000130',
#  '2010-08-14 02:13:00.00000032',
#  '2010-08-14 02:13:00.000000158',
#  '2010-08-14 02:13:00.000000171',
#  '2010-08-14 02:13:00.00000092',
#  '2010-08-14 02:13:00.000000155',
#  '2010-08-14 02:13:00.000000116',
#  '2010-08-14 02:13:00.000000109',
#  '2010-08-14 02:13:00.00000030',
#  '2010-08-14 02:13:00.00000015',
#  '2010-08-14 02:13:00.000000133',
#  '2010-08-14 02:13:00.00000072',
#  '2010-08-14 02:13:00.00000052',
#  '2010-08-14 02:13:00.000000170',
#  '2010-08-14 02:13:00.0000007',
#  '2010-08-14 02:13:00.000000165',
#  '2010-08-14 02:13:00.00000026',
#  '2010-08-14 02:13:00.000000148',
#  '2010-08-14 02:13:00.00000034',
#  '2010-08-14 02:13:00.00000022',
#  '2010-08-14 02:13:00.000000100',
#  '2010-08-14 02:13:00.000000160',
#  '2010-08-14 02:13:00.0000009',
#  '2010-08-14 02:13:00.00000038',
#  '2010-08-14 02:13:00.0000001',
#  ...]

# %%
#### Converting train_x, train_y, test_x into numpy arrays

train_x_arr = train_x.to_numpy()

train_y_arr = np.array(train_y)

test_x_arr = test_x.to_numpy()

# %% [markdown]
# # **Implementing the Model**

# %%
pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.7/dist-packages (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->lightgbm) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->lightgbm) (1.1.0)

# %% [markdown]
# # **Light Gradient Boosting Machine (LGBM)**

# %%
####
# Importing LGBM Regressor

from lightgbm import LGBMRegressor
clf = LGBMRegressor()

# Training the Regressor

clf.fit(train_x_arr,train_y_arr)
# Out:
# LGBMRegressor()

# %%
####
# Predicting test_x using the Regressor

predictions = clf.predict(test_x_arr)

print(predictions)
# Out:
# [ 8.64362012  8.69127557  6.94241014 ... 53.62099923 19.91796084
#   8.40266559]

# %%
####
# Attaching test_key to predictions and adding them in submission data frame

submission = pd.DataFrame()
submission['key'] = test_key
submission['fare_amount'] = list(predictions)

# %%
####
# Prnting the Submission

submission
# Out:
#                               key  fare_amount
# 0     2015-01-27 13:08:24.0000002     8.643620
# 1     2015-01-27 13:08:24.0000003     8.691276
# 2     2011-10-08 11:53:44.0000002     6.942410
# 3     2012-12-01 21:12:12.0000002     7.770083
# 4     2012-12-01 21:12:12.0000003    14.050174
# ...                           ...          ...
# 9909  2015-05-10 12:37:51.0000002     8.813268
# 9910  2015-01-12 17:05:51.0000001     9.483391
# 9911  2015-04-19 20:44:15.0000001    53.620999
# 9912  2015-01-31 01:05:19.0000005    19.917961
# 9913  2015-01-18 14:06:23.0000006     8.402666
#
# [9914 rows x 2 columns]

# %%
####
# Saving submission into a csv file

submission.to_csv('model_submission_1.csv',index=False)

# %%
####
# Submitting submission to kaggle

! kaggle competitions submit -c new-york-city-taxi-fare-prediction -f model_submission_1.csv -m "LGBM Regressor "
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# 100% 453k/453k [00:00<00:00, 1.75MB/s]
# Successfully submitted to New York City Taxi Fare Prediction
